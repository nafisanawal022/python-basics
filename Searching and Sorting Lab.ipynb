# %%
def length(a,i=0):
    try:
        a[0]
        return (length(a[0:-1],i+1))
    except IndexError:
        return i

def maxV(a,b):
    if a>b:
        return a
    else:
        return b
            
def maximum(a,l):
    if l==0:
        return a[0]
    return maxV(a[l-1],maximum(a,l-1))

def search(a,value,i):
    if i>=l:
        return "Value not found"
    elif a[i]==value:
        return i
    else:
        return search(a,value,i+1)

def selection_sort(a,l):
    if l-1==0:
        return a
    else:
        m=maximum(a,l)
        temp=a[l-1]
        a[l-1]=m
        index=search(a,m,0)
        a[index]=temp

    return selection_sort(a,l-1)

def recheck(a,i):
    j=i-1
    while j>=0:
        if a[i]<a[j]:
            temp=a[j]
            a[j]=a[i]
            a[i]=temp
            i=j
        j-=1
    return a      

def insertion_sort (a,i):
    j=i-1  
    if i+1==l:
        return a
    else:
        if(a[i]>a[i+1]):
            temp=a[i]
            a[i]=a[i+1]
            a[i+1]=temp
            recheck(a,i)
    return (insertion_sort(a,i+1))  


def swap_sort(a,i):
    if i==length-1:
        return a
    else:
        
        if (a[i]>a[i+1]):
            print("yes")
            temp=a[i]
            a[i]=a[i+1]
            a[i+1]=temp
        return (swap_sort(a,i+1))
    


a=[2,10,4,3,12,1,5,8]
l=length(a,0)
print("Initial array-",a)
print("Array selection sort-",selection_sort(a,l))
print()
print("--------------------------------------------------------------------------------------")
print()
b=[2,10,4,3,12,1,5,8]
print("Initial array-",b)
print("Array insertion sort-",insertion_sort(a,0))
# Out:
# Initial array- [2, 10, 4, 3, 12, 1, 5, 8]
# Array selection sort- [1, 2, 3, 4, 5, 8, 10, 12]
#
# --------------------------------------------------------------------------------------
#
# Initial array- [2, 10, 4, 3, 12, 1, 5, 8]
# Array insertion sort- [1, 2, 3, 4, 5, 8, 10, 12]

# %%
class Node:
    
    def __init__(self,element,nextN):
        self.element= element
        self.next=nextN
        
    def printNode(self):
        print(self.element, "-", self.next)
        
        
class MyList:
   
    def __init__(self,a):
        self.head = None
        tail = None
        for i in a:
            n=Node(i,None)
            if (self.head is None):
                self.head=n
                tail=n
            else:
                tail.next = n
                tail = n
        
    def printList(self):
        n= self.head
        while (n is not None):
            n.printNode()
            n=n.next
   
    def count(self,node):
    
        if node==None:
            return 0
        return 1+ self.count(node.next)
        
                  
    def minNode(self,head):
        if(head.next==None):
            return head
        else:
            minN=head
            minNRest=self.minNode(head.next)
            if(minNRest.element<head.element):
                minN=minNRest
            return minN
    
    
    def selection_sort(self,head):
        n=head
        if(n==None or n.next==None):
            return
        else:
            min_Node=self.minNode(n)
            min_Node.element,head.element=head.element,min_Node.element
            self.selection_sort(head.next)
            

    def swap_sort(self,head):
        if head.next==None:
            return head
        else:
            if (head.element>head.next.element):
                head.element,head.next.element=head.next.element,head.element
            return(self.swap_sort(head.next))
        
    def bubble_sort(self,l):
        if l==-1:
            return 
        else:
            self.swap_sort(self.head)
            return (self.bubble_sort(l-1))
        

array =([90,38,27,43,3,9,82,1])
list1 = MyList(array)
print("Unsorted")
list1.printList()
print("--------------------------------------------------------------------------------------")
print()
print("Bubble Sort-")
list1.bubble_sort(list1.count(list1.head))
list1.printList()
print("--------------------------------------------------------------------------------------")
array2 =([90,38,27,43,3,9,82,1])
list2 = MyList(array2)
print("Unsorted")
list2.printList()
print("--------------------------------------------------------------------------------------")
print()
print("Selection Sort-")
list2.selection_sort(list2.head)
list2.printList()
# Out:
# Unsorted
# 90 - <__main__.Node object at 0x00000208BB845088>
# 38 - <__main__.Node object at 0x00000208BB845208>
# 27 - <__main__.Node object at 0x00000208BB8454C8>
# 43 - <__main__.Node object at 0x00000208BB845548>
# 3 - <__main__.Node object at 0x00000208BB845588>
# 9 - <__main__.Node object at 0x00000208BB8455C8>
# 82 - <__main__.Node object at 0x00000208BB845608>
# 1 - None
# --------------------------------------------------------------------------------------
#
# Bubble Sort-
# 1 - <__main__.Node object at 0x00000208BB845088>
# 3 - <__main__.Node object at 0x00000208BB845208>
# 9 - <__main__.Node object at 0x00000208BB8454C8>
# 27 - <__main__.Node object at 0x00000208BB845548>
# 38 - <__main__.Node object at 0x00000208BB845588>
# 43 - <__main__.Node object at 0x00000208BB8455C8>
# 82 - <__main__.Node object at 0x00000208BB845608>
# 90 - None
# --------------------------------------------------------------------------------------
# Unsorted
# 90 - <__main__.Node object at 0x00000208BB845888>
# 38 - <__main__.Node object at 0x00000208BB8458C8>
# 27 - <__main__.Node object at 0x00000208BB845908>
# 43 - <__main__.Node object at 0x00000208BB845948>
# 3 - <__main__.Node object at 0x00000208BB845988>
# 9 - <__main__.Node object at 0x00000208BB8459C8>
# 82 - <__main__.Node object at 0x00000208BB845A08>
# 1 - None
# --------------------------------------------------------------------------------------
#
# Selection Sort-
# 1 - <__main__.Node object at 0x00000208BB845888>
# 3 - <__main__.Node object at 0x00000208BB8458C8>
# 9 - <__main__.Node object at 0x00000208BB845908>
# 27 - <__main__.Node object at 0x00000208BB845948>
# 38 - <__main__.Node object at 0x00000208BB845988>
# 43 - <__main__.Node object at 0x00000208BB8459C8>
# 82 - <__main__.Node object at 0x00000208BB845A08>
# 90 - None

# %%
class Node:
    def __init__(self,element,nex,prev):
        self.element= element
        self.next=nex
        self.prev=prev
    
    def printNode(self):
        print(self.element, "-", self.next,"-",self.prev)
        
class DoublyList:
    def __init__(self,a):
        self.head = None
        tail=None
        for i in a:
            n=Node(i,None,None)
            if self.head==None:
                self.head=Node(0,None,None)
                self.head.next=n
                n.next=n.prev=self.head
                self.head.prev=n

            else:
                a=self.head.prev
                a.next=n
                n.prev=a
                n.next=self.head
                self.head.prev=n
                
        count=0
        i=self.head.next
        while(i!=self.head):
            count+=1
            i=i.next
        self.count=count
    
      
    def printList(self):
        n=self.head.next
        while(n!=self.head):
            n.printNode()
            n=n.next
            
    def insert(self,newElement):
        n=Node(newElement,None,None)
        copy=self.search(newElement)
        if (copy==False):
            if(self.head.next==None):
                self.head.next=n
                n.next=n.prev=self.head.next
                self.head.prev=n

            else:
                a=self.head.prev
                a.next=n
                n.prev=a
                n.next=self.head
                self.head.prev=n
                
    def reCheck(self,head):
        if head.prev==self.head.prev:
            return
        else:
            if head.element<head.prev.element:
                head.element,head.prev.element=head.prev.element,head.element
            return(self.reCheck(head.prev))
        
    def insertionSort(self,head):
        if head.next==self.head:
            return 
        else:
            if(head.element>head.next.element):
                head.element,head.next.element=head.next.element,head.element
                self.reCheck(head)
        return(self.insertionSort(head.next))
        

array = ([38,27,43,3,9,82,10])
list1 = DoublyList(array)
print("Initial list")
list1.printList()
print()
print("-----------------")
print("Insertion sort")
list1.insertionSort(list1.head)
list1.printList()
# Out:
# Initial list
# 38 - <__main__.Node object at 0x00000208BB7BB8C8> - <__main__.Node object at 0x00000208BB7BB608>
# 27 - <__main__.Node object at 0x00000208BB7BB488> - <__main__.Node object at 0x00000208BB7BBB48>
# 43 - <__main__.Node object at 0x00000208BB7BB388> - <__main__.Node object at 0x00000208BB7BB8C8>
# 3 - <__main__.Node object at 0x00000208BB7BB0C8> - <__main__.Node object at 0x00000208BB7BB488>
# 9 - <__main__.Node object at 0x00000208BB7BB888> - <__main__.Node object at 0x00000208BB7BB388>
# 82 - <__main__.Node object at 0x00000208BB7BB648> - <__main__.Node object at 0x00000208BB7BB0C8>
# 10 - <__main__.Node object at 0x00000208BB7BB608> - <__main__.Node object at 0x00000208BB7BB888>
#
# -----------------
# Insertion sort
# 3 - <__main__.Node object at 0x00000208BB7BB8C8> - <__main__.Node object at 0x00000208BB7BB608>
# 9 - <__main__.Node object at 0x00000208BB7BB488> - <__main__.Node object at 0x00000208BB7BBB48>
# 10 - <__main__.Node object at 0x00000208BB7BB388> - <__main__.Node object at 0x00000208BB7BB8C8>
# 27 - <__main__.Node object at 0x00000208BB7BB0C8> - <__main__.Node object at 0x00000208BB7BB488>
# 38 - <__main__.Node object at 0x00000208BB7BB888> - <__main__.Node object at 0x00000208BB7BB388>
# 43 - <__main__.Node object at 0x00000208BB7BB648> - <__main__.Node object at 0x00000208BB7BB0C8>
# 82 - <__main__.Node object at 0x00000208BB7BB608> - <__main__.Node object at 0x00000208BB7BB888>

# %%
def maxV(a,b):
    if a>b:
        return a
    else:
        return b
            
def maximum(a,l):
    if l==0:
        return a[0]
    return maxV(a[l-1],maximum(a,l-1))

def search(a,value,i):
    if i>=l:
        return "Value not found"
    elif a[i]==value:
        return i
    else:
        return search(a,value,i+1)

def selection_sort(a,l):
    if l-1==0:
        return a
    else:
        m=maximum(a,l)
        temp=a[l-1]
        a[l-1]=m
        index=search(a,m,0)
        a[index]=temp

    return selection_sort(a,l-1)

def recheck(a,i):
    j=i-1
    while j>=0:
        if a[i]<a[j]:
            temp=a[j]
            a[j]=a[i]
            a[i]=temp
            i=j
        j-=1
    return a   

def binary_search(a,i,length,key):
    if i>length:
        return "Error"
    else:
        mid=int((i+length)/2)
        if(key==a[mid]):
            return ("Found at index "+str(mid))
        elif (key>a[mid]):
            return binary_search(a,mid+1,length,key)
        else:
            return binary_search(a,i,mid-1,key)
        
a=[2,10,4,3,12,1,5]
length=len(a)
selection_sort(a,length)
binary_search(a,0,len(a),4)
# Out:
# [1, 2, 3, 4, 5, 10, 12]
# 'Found at index 3'

# %%
def fibonacci(n):
    
    if (n in memory):
        return memory[n]
    if (n==0 or n==1):
        memory[n]=1
    else:
        memory[n]=(fibonacci(n-1)+fibonacci(n-2))
        
    return memory[n]

size=7
memory=[]
for i in range(0,size+1):
    memory.append(0)
    
print(fibonacci(size))
print(memory)
# Out:
# 13
# [0, 1, 1, 2, 3, 5, 8, 13]

# %%
#Q-1
def length(a,i=0):
    try:
        a[0]
        return (length(a[0:-1],i+1))
    except IndexError:
        return i

def maxV(a,b):
    if a>b:
        return a
    else:
        return b
            
def maximum(a,l):
    if l==0:
        return a[0]
    return maxV(a[l-1],maximum(a,l-1))

def search(a,value,i):
    if i>=l:
        return "Value not found"
    elif a[i]==value:
        return i
    else:
        return search(a,value,i+1)

def selection_sort(a,l):
    if l-1==0:
        return a
    else:
        m=maximum(a,l)
        temp=a[l-1]
        a[l-1]=m
        index=search(a,m,0)
        a[index]=temp

    return selection_sort(a,l-1)

#Q-2
def recheck(a,i):
    j=i-1
    while j>=0:
        if a[i]<a[j]:
            temp=a[j]
            a[j]=a[i]
            a[i]=temp
            i=j
        j-=1
    return a      

def insertion_sort (a,i):
    j=i-1  
    if i+1==l:
        return a
    else:
        if(a[i]>a[i+1]):
            temp=a[i]
            a[i]=a[i+1]
            a[i+1]=temp
            recheck(a,i)
    return (insertion_sort(a,i+1)) 


class Node:
    
    def __init__(self,element,nextN):
        self.element= element
        self.next=nextN
        
    def printNode(self):
        print(self.element, "-", self.next)

        
class MyList:
    
   
    def __init__(self,a):
        self.head = None
        tail = None
        for i in a:
            n=Node(i,None)
            if (self.head is None):
                self.head=n
                tail=n
            else:
                tail.next = n
                tail = n

    def printList(self):
        n= self.head
        while (n is not None):
            n.printNode()
            n=n.next

#Q-3

    def count(self,node):
    
        if node==None:
            return 0
        return 1+ self.count(node.next)
    
    def swap_sort(self,head):
        if head.next==None:
            return head
        else:
            if (head.element>head.next.element):
                head.element,head.next.element=head.next.element,head.element
            return(self.swap_sort(head.next))
        
    def bubble_sort(self,l):
        if l==-1:
            return 
        else:
            self.swap_sort(self.head)
            return (self.bubble_sort(l-1))
        
#Q-4

    def minNode(self,head):
        if(head.next==None):
            return head
        else:
            minN=head
            minNRest=self.minNode(head.next)
            if(minNRest.element<head.element):
                minN=minNRest
            return minN
    
    
    def selection_sort(self,head):
        n=head
        if(n==None or n.next==None):
            return
        else:
            min_Node=self.minNode(n)
            min_Node.element,head.element=head.element,min_Node.element
            self.selection_sort(head.next)

#Q-5            
class NodeDoubly:
    def __init__(self,element,nex,prev):
        self.element= element
        self.next=nex
        self.prev=prev
    
    def printNode(self):
        print(self.element, "-", self.next,"-",self.prev)            
        
class DoublyList:
    def __init__(self,a):
        self.head = None
        tail=None
        for i in a:
            n=NodeDoubly(i,None,None)
            if self.head==None:
                self.head=NodeDoubly(0,None,None)
                self.head.next=n
                n.next=n.prev=self.head
                self.head.prev=n

            else:
                a=self.head.prev
                a.next=n
                n.prev=a
                n.next=self.head
                self.head.prev=n
                
        count=0
        i=self.head.next
        while(i!=self.head):
            count+=1
            i=i.next
        self.count=count
    
      
    def printList(self):
        n=self.head.next
        while(n!=self.head):
            n.printNode()
            n=n.next
                
    def reCheck(self,head):
        if head.prev==self.head.prev:
            return
        else:
            if head.element<head.prev.element:
                head.element,head.prev.element=head.prev.element,head.element
            return(self.reCheck(head.prev))
        
    def insertionSort(self,head):
        if head.next==self.head:
            return 
        else:
            if(head.element>head.next.element):
                head.element,head.next.element=head.next.element,head.element
                self.reCheck(head)
        return(self.insertionSort(head.next))
        

#Q-6
def binary_search(a,i,length,key):
    if i>length:
        return "Error"
    else:
        mid=int((i+length)/2)
        if(key==a[mid]):
            return ("Found at index "+str(mid))
        elif (key>a[mid]):
            return binary_search(a,mid+1,length,key)
        else:
            return binary_search(a,i,mid-1,key)
        
#Q-7
def fibonacci(n):
    
    if (n in memory):
        return memory[n]
    if (n==0 or n==1):
        memory[n]=1
    else:
        memory[n]=(fibonacci(n-1)+fibonacci(n-2))
        
    return memory[n]

#Tester

a=[2,10,4,3,12,1,5,8]
l=length(a,0)
print("Initial array-",a)
print("Array selection sort-",selection_sort(a,l))
print()
print("--------------------------------------------------------------------------------------")
print()
b=[2,10,4,3,12,1,5,8]
print("Initial array-",b)
print("Array insertion sort-",insertion_sort(a,0))
print()
print("--------------------------------------------------------------------------------------")
print()
array =([90,38,27,43,3,9,82,1])
list1 = MyList(array)
print("Unsorted")
list1.printList()
print()
print("--------------------------------------------------------------------------------------")
print("Bubble Sort-")
list1.bubble_sort(list1.count(list1.head))
list1.printList()
print()
print("--------------------------------------------------------------------------------------")
print()
array2 =([90,38,27,43,3,9,82,1])
list2 = MyList(array2)
print("Unsorted")
list2.printList()
print()
print("--------------------------------------------------------------------------------------")
print("Selection Sort-")
list2.selection_sort(list2.head)
list2.printList()
print()
print("--------------------------------------------------------------------------------------")
print()
array = ([38,27,43,3,9,82,10])
list1 = DoublyList(array)
print("Unsorted")
list1.printList()
print()
print("-----------------")
print("Insertion sort-")
list1.insertionSort(list1.head)
list1.printList()
print()
print("--------------------------------------------------------------------------------------")
print()            
a=[2,10,4,3,12,1,5]
length=length(a,0)
selection_sort(a,length)
print(binary_search(a,0,len(a),4))
print()
print("--------------------------------------------------------------------------------------")
print()  
size=7
memory=[]
for i in range(0,size+1):
    memory.append(0)
    
print(fibonacci(size))
# Out:
# Initial array- [2, 10, 4, 3, 12, 1, 5, 8]
# Array selection sort- [1, 2, 3, 4, 5, 8, 10, 12]
#
# --------------------------------------------------------------------------------------
#
# Initial array- [2, 10, 4, 3, 12, 1, 5, 8]
# Array insertion sort- [1, 2, 3, 4, 5, 8, 10, 12]
#
# --------------------------------------------------------------------------------------
#
# Unsorted
# 90 - <__main__.Node object at 0x00000208BB966AC8>
# 38 - <__main__.Node object at 0x00000208BB966B08>
# 27 - <__main__.Node object at 0x00000208BB966108>
# 43 - <__main__.Node object at 0x00000208BB966D88>
# 3 - <__main__.Node object at 0x00000208BB9669C8>
# 9 - <__main__.Node object at 0x00000208BB966F48>
# 82 - <__main__.Node object at 0x00000208BB966A48>
# 1 - None
#
# --------------------------------------------------------------------------------------
# Bubble Sort-
# 1 - <__main__.Node object at 0x00000208BB966AC8>
# 3 - <__main__.Node object at 0x00000208BB966B08>
# 9 - <__main__.Node object at 0x00000208BB966108>
# 27 - <__main__.Node object at 0x00000208BB966D88>
# 38 - <__main__.Node object at 0x00000208BB9669C8>
# 43 - <__main__.Node object at 0x00000208BB966F48>
# 82 - <__main__.Node object at 0x00000208BB966A48>
# 90 - None
#
# --------------------------------------------------------------------------------------
#
# Unsorted
# 90 - <__main__.Node object at 0x00000208BB8EC248>
# 38 - <__main__.Node object at 0x00000208BB8EC308>
# 27 - <__main__.Node object at 0x00000208BB8EC708>
# 43 - <__main__.Node object at 0x00000208BB8EC408>
# 3 - <__main__.Node object at 0x00000208BB8ECA08>
# 9 - <__main__.Node object at 0x00000208BB8ECF08>
# 82 - <__main__.Node object at 0x00000208BB8ECAC8>
# 1 - None
#
# --------------------------------------------------------------------------------------
# Selection Sort-
# 1 - <__main__.Node object at 0x00000208BB8EC248>
# 3 - <__main__.Node object at 0x00000208BB8EC308>
# 9 - <__main__.Node object at 0x00000208BB8EC708>
# 27 - <__main__.Node object at 0x00000208BB8EC408>
# 38 - <__main__.Node object at 0x00000208BB8ECA08>
# 43 - <__main__.Node object at 0x00000208BB8ECF08>
# 82 - <__main__.Node object at 0x00000208BB8ECAC8>
# 90 - None
#
# --------------------------------------------------------------------------------------
#
# Unsorted
# 38 - <__main__.NodeDoubly object at 0x00000208BB828548> - <__main__.NodeDoubly object at 0x00000208BB828788>
# 27 - <__main__.NodeDoubly object at 0x00000208BB828E88> - <__main__.NodeDoubly object at 0x00000208BB828688>
# 43 - <__main__.NodeDoubly object at 0x00000208BB828148> - <__main__.NodeDoubly object at 0x00000208BB828548>
# 3 - <__main__.NodeDoubly object at 0x00000208BB828288> - <__main__.NodeDoubly object at 0x00000208BB828E88>
# 9 - <__main__.NodeDoubly object at 0x00000208BB8286C8> - <__main__.NodeDoubly object at 0x00000208BB828148>
# 82 - <__main__.NodeDoubly object at 0x00000208BB828FC8> - <__main__.NodeDoubly object at 0x00000208BB828288>
# 10 - <__main__.NodeDoubly object at 0x00000208BB828788> - <__main__.NodeDoubly object at 0x00000208BB8286C8>
#
# -----------------
# Insertion sort-
# 3 - <__main__.NodeDoubly object at 0x00000208BB828548> - <__main__.NodeDoubly object at 0x00000208BB828788>
# 9 - <__main__.NodeDoubly object at 0x00000208BB828E88> - <__main__.NodeDoubly object at 0x00000208BB828688>
# 10 - <__main__.NodeDoubly object at 0x00000208BB828148> - <__main__.NodeDoubly object at 0x00000208BB828548>
# 27 - <__main__.NodeDoubly object at 0x00000208BB828288> - <__main__.NodeDoubly object at 0x00000208BB828E88>
# 38 - <__main__.NodeDoubly object at 0x00000208BB8286C8> - <__main__.NodeDoubly object at 0x00000208BB828148>
# 43 - <__main__.NodeDoubly object at 0x00000208BB828FC8> - <__main__.NodeDoubly object at 0x00000208BB828288>
# 82 - <__main__.NodeDoubly object at 0x00000208BB828788> - <__main__.NodeDoubly object at 0x00000208BB8286C8>
#
# --------------------------------------------------------------------------------------
#
# Found at index 3
#
# --------------------------------------------------------------------------------------
#
# 13
